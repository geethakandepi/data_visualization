# %%
# %pip install -U google-genai
# Out:
# Collecting google-genai
#   Using cached google_genai-2.16.0-py3-none-any.whl.metadata (56 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (4.13.0)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Using cached google_auth-2.56.2-py3-none-any.whl.metadata (6.0 kB)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (2.13.3)
# Collecting requests<3.0.0,>=2.28.1 (from google-genai)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.13)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: cryptography>=41.0.5 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (47.0.0)
# Collecting certifi (from httpx<1.0.0,>=0.28.1->google-genai)
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1.0.0,>=0.28.1->google-genai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.28.1->google-genai)
#   Using cached charset_normalizer-3.4.9-cp314-cp314-win_amd64.whl.metadata (42 kB)
# Collecting urllib3<3,>=1.26 (from requests<3.0.0,>=2.28.1->google-genai)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.3)
# Using cached google_genai-2.16.0-py3-none-any.whl (1.1 MB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached google_auth-2.56.2-py3-none-any.whl (258 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.9-cp314-cp314-win_amd64.whl (162 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached certifi-2026.7.22-py3-none-any.whl (136 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: urllib3, tenacity, sniffio, pyasn1-modules, distro, charset_normalizer, certifi, requests, httpcore, httpx, google-auth, google-genai
#
#    ----------------------------------------  0/12 [urllib3]
#    --- ------------------------------------  1/12 [tenacity]
#    ---------- -----------------------------  3/12 [pyasn1-modules]
#    ---------- -----------------------------  3/12 [pyasn1-modules]
#    ---------- -----------------------------  3/12 [pyasn1-modules]
#    ---------- -----------------------------  3/12 [pyasn1-modules]
#    ---------- -----------------------------  3/12 [pyasn1-modules]
#    ---------------- -----------------------  5/12 [charset_normalizer]
#    ----------------------- ----------------  7/12 [requests]
#    -------------------------- -------------  8/12 [httpcore]
#    -------------------------- -------------  8/12 [httpcore]
#    ------------------------------ ---------  9/12 [httpx]
#    --------------------------------- ------ 10/12 [google-auth]
#    --------------------------------- ------ 10/12 [google-auth]
#    --------------------------------- ------ 10/12 [google-auth]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ------------------------------------ --- 11/12 [google-genai]
#    ---------------------------------------- 12/12 [google-genai]
#
# Successfully installed certifi-2026.7.22 charset_normalizer-3.4.9 distro-1.9.0 google-auth-2.56.2 google-genai-2.16.0 httpcore-1.0.9 httpx-0.28.1 pyasn1-modules-0.4.2 requests-2.34.2 sniffio-1.3.1 tenacity-9.1.4 urllib3-2.7.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script distro.exe is installed in 'c:\Users\GEETHA\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\GEETHA\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\GEETHA\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\geetha\appdata\local\programs\python\python314\lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai
import getpass

# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("api_key")

print(api_key[:5])
# Out:
# AQ.Ab

# %%
from google import genai

client = genai.Client(api_key=api_key)
